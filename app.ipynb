# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %matplotlib inline

image = cv.imread("me.jpeg")
image = cv.cvtColor(image, cv.COLOR_RGB2BGR)

plt.axis('off')
plt.imshow(image)
plt.show()
